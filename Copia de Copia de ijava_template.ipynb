// %% [markdown]
// Ejercicios programación

// %%
!apt update -q
!apt-get install -q openjdk-11-jdk-headless
!curl -L https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip -o ijava-kernel.zip
!unzip -q ijava-kernel.zip -d ijava-kernel && cd ijava-kernel && python3 install.py --sys-prefix
!jupyter kernelspec list

// %%
String printBinary(String binary, int blockSize, String separator) {
        List<String> result = new ArrayList<>();
        int index = 0;
        while (index < binary.length()) {
            result.add(binary.substring(index, Math.min(index + blockSize, binary.length())));
            index += blockSize;
        }

        return result.stream().collect(java.util.stream.Collectors.joining(separator));
    }
void intToBin(int input){
    String result = Integer.toBinaryString(input);
    String resultWithPadding = String.format("%32s", result).replaceAll(" ", "0");
    System.out.println(printBinary(resultWithPadding, 4, " ")); 
}

// %%
//ejercicio 1
byte b0 = 122;
byte b1 = 14;

b0+b1;

long b0 = 122; long b1 = 1;//123
int r = (int)(b0 + b1);
System.out.println(r);//las variables que reconoce son las últimas que se han declarado como b1 y b0. La variable temporal pierde validez.

// %%
//ejercicio 2
char c = 'a';
int n = c;
 System.out.println(n);// el resultado es el código de tecla ASCII que tiene asignado la letra "a"
short s = c;
System.out.println(s);//el resultado se expresa como un único cáracter en vez de como código de tecla ASSCII, debido a esto el dato del resultado no es compatible con las varibles de tipo short

// %%
//ejercicio 3
char c = 'a';
Short s = (short)c;
System.out.println(s);//Escribiendo short al lado del valor de la variable c, le estamos pidiendo que el resultado lo exprese en una variable de tipo short, por eso el resultado es el código de tecla ASCII

// %%
//pregunta 4
short s = (short) 32000;
System.out.println(s);

short s = (short)35000;
System.out.println(s);// el segundo resultado se pasa del límete de números que puede contener un short ( -32,768 a 32,767) por eso retorna al número inicial -32768 y luego le suma la diferencia

// %%
//ejercicio 5
var v = 5.0;//una variable de tipo float
var v0 = 5;//seria una variable de tipo int
var v1 = v + v0;
System.out.println(v1);//la suma de las variables v y v0 hace que la variable v1 se convierta en float

// %%
//ejercicio 8
char c = 'a' , c1 = 1;
int c2 = c + c1;
System.out.println(c2);// es necesatio cambiar el tipo de variable de c2 de char a int para que reconozca el resultado, ya que no se puede expresar como un caracter el resultado de una suma.

// %%
//ejercio 9
var h = 4 * 4f + (4.0 + 4);

float f = h;
System.out.println(f);//obtenemos este resultado porque nosotros exigimos que la variable exprese una variable float y el resultado es un double

// %%
//ejercicio 9

var h = 4f * 4f + (4.0f + 4f);

float f = h;
System.out.println(f);// es necesario cambiar todos los números a float para que el resultado pueda ejecutarse

// %%
//ejercicio 10
byte b0 = 4 , b1 = -4 , b2 = 12;
boolean bol1 = b0 == b2 / 3;//cumple la condición de que b0 es equivalente a b2/3 y el resultado es true
boolean blo2 = b0 + b1; //la variable no cumple una condición en la cual se pueda responder con tru o false y da error
boolean bol3 = b0 + b1 > b2;//no cumple el requisito de que b0+b1 es más grande que b2 y da como resultado false
System.out.println(bol1);
System.out.println(bol2);
System.out.println(bol3);
